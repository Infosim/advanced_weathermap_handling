# %% [markdown]
# <center><img src='https://www.intel.com/content/dam/develop/external/us/en/images/infosim-logo-746616.png' style="width:300px"></center>

# %% [markdown]
# # StableNet<sup>®</sup> Weather Map Transfer
#
# ## Introduction
# The only non-trivial part for transferring a Weather Map from one StableNet server to a another one via REST API (and thus, the only reason for the existence of this script) is handling the references to objects in StableNet.  For each "relevant" tag domain this script allows to define a non-empty and finite list of python regular expressions characterizing tag domains.  If there are two objects from the respective domain (one on each server) whose tag values are equal on all these tag categories, then this script assumes these objects as equal and replaces the references to the first objects with references to the second object.
#
# The following inputs need to be specified:
# * IP-address, port, username, and password for the two StableNet servers (in "Provide server credentials)
# * Id of the Weather Map that shall be transferred (in "Define input parameters for script")
# * Regular Expressions for relevant tag categories per domain (already preselected, in "Define input parameters for script")

# %% [markdown]
# ## Program

# %% [markdown]
# ### Imports and code definitions
# #### Import necessary python modules

# %%
import warnings
import requests
from requests.auth import HTTPBasicAuth
import getpass
from xml.etree import ElementTree
import xml.dom.minidom # for pretty printing XML
import re # for regular expressions
import json
import sys

# %% [markdown]
# #### Function to request Weather Map from server

# %%
def request_weather_map():
    resp = requests.get(
        "https://{}:{}/rest/weathermaps/get/{}"
        .format(a_server_ip, a_server_port, wmap_id), 
        verify=False, 
        auth=HTTPBasicAuth(a_username, a_pw)
    )
    wmap = ElementTree.fromstring(resp.content)
    if wmap.tag == 'error':
        print('Weather Map with id {} does not exist on server {}:{}'\
              .format(wmap_id, a_server_ip, a_server_port))
        sys.exit()
    #print (xml.dom.minidom.parseString(resp.content.decode('utf-8')).toprettyxml())
    return wmap

# %% [markdown]
# #### Function to request the tags of a StableNet object (using the REST endpoint /rest/tag/list)

# %%
def request_tags_in_source_system():
    url = "https://{}:{}/rest/tag/list?includeAttributeTags=true"\
        "&includeDirectTags=false&includeInheritedTags=true"\
        .format(a_server_ip, a_server_port)
    return requests.post(
        url, 
        verify=False, 
        auth=HTTPBasicAuth(a_username, a_pw), 
        data='<taggablereference domain="{}" obid="{}" />'.format(ref_domain, ref_id), 
        headers = {'Content-Type': 'application/xml'}
    )

# %% [markdown]
# #### Functions to obtain the obid of a StableNet object on the target server (using tag categories that can be specified below and the REST endpoint /rest/tag/query)

# %%
def get_valuetagfilter(cat, val):
    return '<valuetagfilter filtervalue="{}">\
                <tagcategory key = "{}"/>\
            </valuetagfilter>'.format(val, cat)
    
def compute_id_in_target_system():
    lookups = []
    for tag_key in tag_keys[ref_domain]:
        pattern = re.compile(
            '<tag id="[^"]*" key="([^"]*{}[^"]*)"'\
            ' value="(?P<tagvalue>[^"]*)"[^>]*>'\
            .format(tag_key.replace('.', '[^"]'))
        )
        lookups.append(pattern.search(a_tags.content.decode('utf-8')))
    flag = True
    for lookup in lookups:
        flag = True if (hasattr(lookup, 'group') and flag) else False
    if not flag:
        return []
    url = 'https://{}:{}/rest/tag/query'.format(b_server_ip, b_server_port)
    filter = ''
    for lookup in lookups:
        tag_key = lookup.group(1)
        tag_value = lookup.group('tagvalue')
        filter += get_valuetagfilter(tag_key, tag_value)
    filter = '<andtagfilter>' + filter + '</andtagfilter>'
    domain_to_be_queried = ref_domain[0].upper() + ref_domain[1:]
    tag_category_to_be_queried = domain_to_be_queried + ' ID' if ref_domain != 'module' else 'Device ' + domain_to_be_queried + ' ID'
    query = '<taggablelistqueryinput domain="{}">\
                <tagcategories>\
                    <tagcategory key="{}"/>\
                </tagcategories>'.format(domain_to_be_queried, tag_category_to_be_queried) +\
                filter +\
            '</taggablelistqueryinput>'
    resp = requests.post(
        url, 
        data = query,
        verify = False, 
        auth = HTTPBasicAuth(b_username, b_pw),
        headers = {'Content-Type': 'application/xml'}
    )
    obj = ElementTree.fromstring(resp.content)
    obid = ''
    for element in obj.iter():
        if element.tag == 'tag':
            if element.get('key') == tag_category_to_be_queried:
                obid = element.get('value')
        if obid != '':
            break
    return obid

# %% [markdown]
# ### Enter server credentials & Weather Map ID to be used as base

# %% [markdown]
# ### Actual program code to handle Weather Maps

# %% [markdown]
# <span style="color:red">Select this cell and run in menu: "Run > Run All Above Selected Cell"</span>

# %% [markdown]
# #### Provide server credentials

# %%
#Credentials of server a (source system)
a_server_ip = '10.20.20.21'
a_server_port = '5443'
a_username = 'infosim'
a_pw = getpass.getpass(
    'Enter password for user ' + a_username + ' on server A:'
)

#Credentials of server b (destination system)
b_server_ip = '10.20.20.162'
b_server_port = '5443'
b_username = 'infosim'
b_pw=getpass.getpass(
    'Enter password for user ' + b_username + ' on server B:'
)
# Out:
# Enter password for user infosim on server A: ·········
# Enter password for user infosim on server B: ·········

# %% [markdown]
# #### Check server credentials and get List of Weather Maps from Server

# %%
warnings.filterwarnings("ignore")
resp = requests.get(
    "https://"+a_server_ip+":"+a_server_port+"/rest/weathermaps/list", 
    verify = False, 
    auth = HTTPBasicAuth(a_username, a_pw))
#print(xml.dom.minidom.parseString(resp.content.decode('utf-8')).toprettyxml())
tree = ElementTree.fromstring(resp.content)
if tree.tag == 'html':
    print('wrong credentials on source server inserted')
    sys.exit()
for wmap in tree:
    wmapname = wmap.get('name') if wmap.get('name') is not None else ''
    print('Weather Map ' + wmap.get('obid') + ': ' + wmapname)
#print (xml.dom.minidom.parseString(resp.content.decode('utf-8')).toprettyxml())
# Out:
# Weather Map 1019: 9_Office Ship
# Weather Map 1037: 2020-02-26 berlin.routerlab.infosim.net
# Weather Map 1099: Aarnet
# Weather Map 1056: ab
# Weather Map 1042: abc
# Weather Map 1044: abc2
# Weather Map 1100: Abilene
# Weather Map 1101: Abvt
# Weather Map 1102: Aconet
# Weather Map 1103: Agis
# Weather Map 1104: Ai3
# Weather Map 1105: Airtel
# Weather Map 1743: All Devices - 16:9 - Default Icon
# Weather Map 1688: All Devices with Geo Coordinates (auto created by Workflow Job)
# Weather Map 1106: Amres
# Weather Map 1107: Ans
# Weather Map 1109: Arn
# Weather Map 1390: ARN0DB0201
# Weather Map 1108: Arnes
# Weather Map 1111: Arpanet19706
# Weather Map 1112: Arpanet19719
# Weather Map 1113: Arpanet19723
# Weather Map 1114: Arpanet19728
# Weather Map 1110: Arpanet196912
# Weather Map 1115: AsnetAm
# Weather Map 1116: Atmnet
# Weather Map 1117: AttMpls
# Weather Map 1118: Azrena
# Weather Map 1388: bach.infosim.net
# Weather Map 1119: Bandcon
# Weather Map 1721: BASIS-Netz
# Weather Map 1788: BASIS-Netz(RANDOM STATS)
# Weather Map 1120: Basnet
# Weather Map 1121: Bbnplanet
# Weather Map 1122: Bellcanada
# Weather Map 1123: Bellsouth
# Weather Map 1124: Belnet2003
# Weather Map 1125: Belnet2004
# Weather Map 1126: Belnet2005
# Weather Map 1127: Belnet2006
# Weather Map 1128: Belnet2007
# Weather Map 1129: Belnet2008
# Weather Map 1130: Belnet2009
# Weather Map 1131: Belnet2010
# Weather Map 1002: berlin.routerlab.infosim.net
# Weather Map 1132: BeyondTheNetwork
# Weather Map 1133: Bics
# Weather Map 1689: Bicycle Stations Oslo
# Weather Map 1675: BikeRental GeoMap from Workflowjob
# Weather Map 1691: BikeRental GeoMap Nextbike Würzburg from Workflowjob
# Weather Map 1742: BikeRentalOslo - AutoAspectRatio - Icon 10003
# Weather Map 1716: BikeRentalWue - 3:2 - Icon 10003
# Weather Map 1789: BikeRentalWue - 3:2 - Icon 10003
# Weather Map 1134: Biznet
# Weather Map 1389: BMW-Plan Test 1
# Weather Map 1387: boron - abc
# Weather Map 1135: Bren
# Weather Map 1136: BsonetEurope
# Weather Map 1137: BtAsiaPac
# Weather Map 1138: BtEurope
# Weather Map 1139: BtLatinAmerica
# Weather Map 1140: BtNorthAmerica
# Weather Map 1004: CA
# Weather Map 1141: Canerie
# Weather Map 1142: Carnet
# Weather Map 1007: CB2
# Weather Map 1143: Cernet
# Weather Map 1144: Cesnet1993
# Weather Map 1145: Cesnet1997
# Weather Map 1146: Cesnet1999
# Weather Map 1147: Cesnet2001
# Weather Map 1148: Cesnet200304
# Weather Map 1149: Cesnet200511
# Weather Map 1150: Cesnet200603
# Weather Map 1151: Cesnet200706
# Weather Map 1152: Cesnet201006
# Weather Map 1153: Chinanet
# Weather Map 1154: Claranet
# Weather Map 1155: Cogentco
# Weather Map 1156: Colt
# Weather Map 1157: Columbus
# Weather Map 1158: Compuserve
# Weather Map 1159: CrlNetworkServices
# Weather Map 1160: Cudi
# Weather Map 1161: Cwix
# Weather Map 1162: Cynet
# Weather Map 1163: Darkstrand
# Weather Map 1164: Dataxchange
# Weather Map 1055: def
# Weather Map 1165: Deltacom
# Weather Map 1166: DeutscheTelekom
# Weather Map 1167: Dfn
# Weather Map 1168: DialtelecomCz
# Weather Map 1169: Digex
# Weather Map 1012: dyn weathermap
# Weather Map 1170: Easynet
# Weather Map 1171: Eenet
# Weather Map 1172: EliBackbone
# Weather Map 1173: Epoch
# Weather Map 1174: Ernet
# Weather Map 1175: Esnet
# Weather Map 1176: Eunetworks
# Weather Map 1177: Evolink
# Weather Map 1032: example1
# Weather Map 1033: example2
# Weather Map 1034: example3
# Weather Map 1035: example4
# Weather Map 1178: Fatman
# Weather Map 1179: Fccn
# Weather Map 1180: Forthnet
# Weather Map 1181: Funet
# Weather Map 1182: Gambia
# Weather Map 1183: Garr199901
# Weather Map 1184: Garr199904
# Weather Map 1185: Garr199905
# Weather Map 1186: Garr200109
# Weather Map 1187: Garr200112
# Weather Map 1188: Garr200212
# Weather Map 1189: Garr200404
# Weather Map 1190: Garr200902
# Weather Map 1191: Garr200908
# Weather Map 1192: Garr200909
# Weather Map 1193: Garr200912
# Weather Map 1194: Garr201001
# Weather Map 1195: Garr201003
# Weather Map 1196: Garr201004
# Weather Map 1197: Garr201005
# Weather Map 1198: Garr201007
# Weather Map 1199: Garr201008
# Weather Map 1200: Garr201010
# Weather Map 1201: Garr201012
# Weather Map 1202: Garr201101
# Weather Map 1203: Garr201102
# Weather Map 1204: Garr201103
# Weather Map 1205: Garr201104
# Weather Map 1206: Garr201105
# Weather Map 1207: Garr201107
# Weather Map 1208: Garr201108
# Weather Map 1209: Garr201109
# Weather Map 1210: Garr201110
# Weather Map 1211: Garr201111
# Weather Map 1212: Garr201112
# Weather Map 1213: Garr201201
# Weather Map 1214: Gblnet
# Weather Map 1215: Geant2001
# Weather Map 1216: Geant2009
# Weather Map 1217: Geant2010
# Weather Map 1218: Geant2012
# Weather Map 1596: GeoMapTest
# Weather Map 1714: GEOMAPTEST_OBIDS canBeDeleted
# Weather Map 1219: Getnet
# Weather Map 1220: Globalcenter
# Weather Map 1221: Globenet
# Weather Map 1222: Goodnet
# Weather Map 1223: Grena
# Weather Map 1224: Gridnet
# Weather Map 1225: Grnet
# Weather Map 1226: GtsCe
# Weather Map 1227: GtsCzechRepublic
# Weather Map 1228: GtsHungary
# Weather Map 1229: GtsPoland
# Weather Map 1230: GtsRomania
# Weather Map 1231: GtsSlovakia
# Weather Map 1232: Harnet
# Weather Map 1233: Heanet
# Weather Map 1234: HiberniaCanada
# Weather Map 1235: HiberniaGlobal
# Weather Map 1236: HiberniaIreland
# Weather Map 1237: HiberniaNireland
# Weather Map 1238: HiberniaUk
# Weather Map 1239: HiberniaUs
# Weather Map 1240: Highwinds
# Weather Map 1241: HostwayInternational
# Weather Map 1242: HurricaneElectric
# Weather Map 1243: Ibm
# Weather Map 1244: Iij
# Weather Map 1245: Iinet
# Weather Map 1246: Ilan
# Weather Map 1575: imagetest
# Weather Map 1247: Integra
# Weather Map 1248: Intellifiber
# Weather Map 1249: Internetmci
# Weather Map 1250: Internode
# Weather Map 1251: Interoute
# Weather Map 1252: Intranetwork
# Weather Map 1253: Ion
# Weather Map 1254: IowaStatewideFiberMap
# Weather Map 1255: Iris
# Weather Map 1256: Istar
# Weather Map 1257: Itnet
# Weather Map 1258: Janetbackbone
# Weather Map 1259: JanetExternal
# Weather Map 1260: Janetlense
# Weather Map 1261: Jgn2Plus
# Weather Map 1060: JUMPHOSTWIN7.root.infosim.net
# Weather Map 1262: Karen
# Weather Map 1576: Karte
# Weather Map 1263: Kdl
# Weather Map 1264: KentmanApr2007
# Weather Map 1265: KentmanAug2005
# Weather Map 1266: KentmanFeb2008
# Weather Map 1267: KentmanJan2011
# Weather Map 1268: KentmanJul2005
# Weather Map 1269: Kreonet
# Weather Map 1270: LambdaNet
# Weather Map 1271: Latnet
# Weather Map 1734: Latnet(RANDOM STATS)
# Weather Map 1737: Latnet(RANDOM STATS)
# Weather Map 1272: Layer42
# Weather Map 1273: Litnet
# Weather Map 1045: map3
# Weather Map 1046: map4
# Weather Map 1047: map4
# Weather Map 1048: map5
# Weather Map 1049: map6
# Weather Map 1050: map7
# Weather Map 1051: map8
# Weather Map 1053: map9
# Weather Map 1054: map10
# Weather Map 1059: map11-grouped
# Weather Map 1061: map12
# Weather Map 1062: map13
# Weather Map 1063: map14
# Weather Map 1064: map15
# Weather Map 1065: map16
# Weather Map 1066: map17
# Weather Map 1067: map18
# Weather Map 1068: map19
# Weather Map 1069: map20
# Weather Map 1070: map21
# Weather Map 1071: map22
# Weather Map 1072: map23
# Weather Map 1074: map24
# Weather Map 1075: map26
# Weather Map 1367: map30
# Weather Map 1372: map30
# Weather Map 1431: map30
# Weather Map 1432: map30
# Weather Map 1375: map31
# Weather Map 1385: map32
# Weather Map 1392: map32
# Weather Map 1396: map33
# Weather Map 1601: map34
# Weather Map 1398: map35
# Weather Map 1399: map35
# Weather Map 1393: map40
# Weather Map 1455: map40
# Weather Map 1374: map41
# Weather Map 1395: map42
# Weather Map 1436: map43
# Weather Map 1437: map43
# Weather Map 1438: map43
# Weather Map 1439: map43
# Weather Map 1440: map43
# Weather Map 1442: map43
# Weather Map 1443: map43
# Weather Map 1444: map43
# Weather Map 1445: map43
# Weather Map 1562: map43
# Weather Map 1092: map50
# Weather Map 1093: map50
# Weather Map 1095: map60
# Weather Map 1096: map60
# Weather Map 1362: map70
# Weather Map 1274: Marnet
# Weather Map 1275: Marwan
# Weather Map 1276: Missouri
# Weather Map 1277: Mren
# Weather Map 1278: Myren
# Weather Map 1279: Napnet
# Weather Map 1280: Navigata
# Weather Map 1281: Netrail
# Weather Map 1282: NetworkUsa
# Weather Map 1283: Nextgen
# Weather Map 1284: Niif
# Weather Map 1285: Noel
# Weather Map 1286: Nordu1989
# Weather Map 1287: Nordu1997
# Weather Map 1288: Nordu2005
# Weather Map 1289: Nordu2010
# Weather Map 1290: Nsfcnet
# Weather Map 1291: Nsfnet
# Weather Map 1292: Ntelos
# Weather Map 1293: Ntt
# Weather Map 1017: office-network
# Weather Map 1027: office-network_TF_DH
# Weather Map 1294: Oteglobe
# Weather Map 1295: Oxford
# Weather Map 1296: Pacificwave
# Weather Map 1297: Packetexchange
# Weather Map 1298: Padi
# Weather Map 1299: Palmetto
# Weather Map 1300: Peer1
# Weather Map 1301: Pern
# Weather Map 1302: PionierL1
# Weather Map 1303: PionierL3
# Weather Map 1304: Psinet
# Weather Map 1305: Quest
# Weather Map 1306: RedBestel
# Weather Map 1307: Rediris
# Weather Map 1308: Renam
# Weather Map 1309: Renater1999
# Weather Map 1310: Renater2001
# Weather Map 1311: Renater2004
# Weather Map 1312: Renater2006
# Weather Map 1313: Renater2008
# Weather Map 1314: Renater2010
# Weather Map 1001: research21.infosim.net
# Weather Map 1315: Restena
# Weather Map 1316: Reuna
# Weather Map 1317: Rhnet
# Weather Map 1318: Rnp
# Weather Map 1320: Roedunet
# Weather Map 1319: RoedunetFibre
# Weather Map 1321: Sago
# Weather Map 1322: Sanet
# Weather Map 1323: Sanren
# Weather Map 1324: Savvis
# Weather Map 1427: send-johannes
# Weather Map 1428: send-johannes2
# Weather Map 1429: send-johannes3
# Weather Map 1430: send-johannes4
# Weather Map 1003: Sendate Review Ryu Weathermap
# Weather Map 1325: Shentel
# Weather Map 1326: Sinet
# Weather Map 1327: Singaren
# Weather Map 1328: Spiralight
# Weather Map 1329: Sprint
# Weather Map 1330: Sunet
# Weather Map 1331: Surfnet
# Weather Map 1052: sw-amsterdam_2020-03-26
# Weather Map 1332: Switch
# Weather Map 1333: SwitchL3
# Weather Map 1334: Syringa
# Weather Map 1335: TataNld
# Weather Map 1336: Telcove
# Weather Map 1337: Telecomserbia
# Weather Map 1574: test
# Weather Map 1018: test2
# Weather Map 1006: test weathermap1
# Weather Map 1023: TFdemo
# Weather Map 1338: Tinet
# Weather Map 1339: TLex
# Weather Map 1341: Tw
# Weather Map 1340: Twaren
# Weather Map 1342: Ulaknet
# Weather Map 1343: UniC
# Weather Map 1344: Uninet
# Weather Map 1345: Uninett2010
# Weather Map 1346: Uninett2011
# Weather Map 1347: Uran
# Weather Map 1348: UsCarrier
# Weather Map 1349: UsSignal
# Weather Map 1350: Uunet
# Weather Map 1351: Vinaren
# Weather Map 1352: VisionNet
# Weather Map 1791: vLab
# Weather Map 1792: vLab (CLONED FROM 10.20.20.46) (Availability in detail)
# Weather Map 1797: vLab - Structure (CLONED FROM 10.20.20.46)
# Weather Map 1772: vLab_TechTalk
# Weather Map 1353: VtlWavenet2008
# Weather Map 1354: VtlWavenet2011
# Weather Map 1355: WideJpn
# Weather Map 1356: Xeex
# Weather Map 1357: Xspedius
# Weather Map 1358: York
# Weather Map 1359: Zamren

# %% [markdown]
# #### Define input parameters for script
# For each tag domain specify regular expressions for the tag categories which shall be used to identify objects on the two servers.

# %%
wmap_id = '1791'
#tag_keys[dom] must be a list of Python regex
#that specify the tag categories over which the objects
#of the domain dom are identified on both servers.  The
#regex should not contain the symbol '"'.
#Objects are identified iff they agree on all specified
#tag categories.
tag_keys = {}
tag_keys['device'] = ['Device Name']
tag_keys['measurement'] = ['[m,M]easure.* [n,N]ame']
tag_keys['interface'] = ['Device Name', 'Inter.* Name']
tag_keys['monitor'] = ["Moni.* Name"]
tag_keys['link'] = ['[L,l]ink Source Device Name', '[L,l]ink Dest.* Device Name','[L,l]ink Source Inter.* Name', '[L,l]ink Dest.*Inter.* Name']
tag_keys['service'] = ['Service Name']
tag_keys['module'] = ['Device Module Name', 'Device Name']

# %% [markdown]
# #### Transfer the Weather Map

# %%
print('Transferring map '+ wmap_id)
wmap = request_weather_map()
for element in wmap.iter():
    if not element.tag.endswith('reference'):
        continue
    ref_id = element.get('obid')
    ref_domain = element.get('domain')
    a_tags = request_tags_in_source_system()
    target_id = compute_id_in_target_system()
    if target_id != '':
        print('{:22}'.format('Domain: ' + ref_domain) +
                'OBID on Server A: {}, OBID on Server B: {}'
                .format(element.get('obid'), target_id))
        element.set('obid',target_id)
    else: #object not found on target system
        print('{:22}'.format('Domain: ' + ref_domain) +
                'OBID on Server A: {}, not found on Server B'
                .format(element.get('obid')))
        element.set('obid','')
print(wmap.get('name') + ' transferred from ' + a_server_ip + ' to ' + b_server_ip)    
wmap.set('name',wmap.get('name') +' (CLONED FROM ' + a_server_ip + ')')
final_map = ElementTree.tostring(wmap)    
resp = requests.post(
    "https://{}:{}/rest/weathermaps/add/"\
        .format(b_server_ip, b_server_port), 
    verify=False,
    auth=HTTPBasicAuth(b_username, b_pw), 
    data=final_map,
    headers={'Content-Type': 'application/xml'}
)
# Out:
# Transferring map 1791
# Domain: device        OBID on Server A: 3057, OBID on Server B: 1039
# Domain: device        OBID on Server A: 3060, OBID on Server B: 1040
# Domain: device        OBID on Server A: 3062, OBID on Server B: 1043
# Domain: device        OBID on Server A: 3063, OBID on Server B: 1044
# Domain: device        OBID on Server A: 3058, OBID on Server B: 1041
# Domain: device        OBID on Server A: 3061, OBID on Server B: 1045
# Domain: device        OBID on Server A: 3059, OBID on Server B: 1042
# Domain: device        OBID on Server A: 1061, OBID on Server B: 1037
# Domain: measurement   OBID on Server A: 2930, OBID on Server B: 1807
# Domain: device        OBID on Server A: 3064, OBID on Server B: 1020
# Domain: device        OBID on Server A: 3066, OBID on Server B: 1022
# Domain: device        OBID on Server A: 3067, OBID on Server B: 1023
# Domain: device        OBID on Server A: 3068, OBID on Server B: 1024
# Domain: device        OBID on Server A: 3070, OBID on Server B: 1026
# Domain: device        OBID on Server A: 3069, OBID on Server B: 1025
# Domain: interface     OBID on Server A: 6119, OBID on Server B: 1683
# Domain: interface     OBID on Server A: 6099, OBID on Server B: 1671
# Domain: link          OBID on Server A: 7828, OBID on Server B: 1142
# Domain: interface     OBID on Server A: 6137, OBID on Server B: 1722
# Domain: interface     OBID on Server A: 6087, OBID on Server B: 1653
# Domain: link          OBID on Server A: 7839, OBID on Server B: 1148
# Domain: interface     OBID on Server A: 6103, OBID on Server B: 1679
# Domain: interface     OBID on Server A: 6141, OBID on Server B: 1716
# Domain: interface     OBID on Server A: 6129, OBID on Server B: 1664
# Domain: interface     OBID on Server A: 6091, OBID on Server B: 1654
# Domain: link          OBID on Server A: 7843, OBID on Server B: 1123
# Domain: interface     OBID on Server A: 6103, OBID on Server B: 1679
# Domain: interface     OBID on Server A: 6087, OBID on Server B: 1653
# Domain: link          OBID on Server A: 7838, OBID on Server B: 1128
# Domain: interface     OBID on Server A: 6131, OBID on Server B: 1660
# Domain: interface     OBID on Server A: 6137, OBID on Server B: 1722
# Domain: link          OBID on Server A: 7825, not found on Server B
# Domain: interface     OBID on Server A: 6100, OBID on Server B: 1675
# Domain: interface     OBID on Server A: 6148, OBID on Server B: 1694
# Domain: link          OBID on Server A: 7855, OBID on Server B: 1124
# Domain: interface     OBID on Server A: 6092, OBID on Server B: 1648
# Domain: interface     OBID on Server A: 6129, OBID on Server B: 1664
# Domain: interface     OBID on Server A: 6127, OBID on Server B: 1658
# Domain: interface     OBID on Server A: 6154, OBID on Server B: 1707
# Domain: interface     OBID on Server A: 6156, OBID on Server B: 1706
# Domain: interface     OBID on Server A: 6139, OBID on Server B: 1713
# Domain: link          OBID on Server A: 7823, OBID on Server B: 1154
# Domain: interface     OBID on Server A: 6131, OBID on Server B: 1660
# Domain: interface     OBID on Server A: 6100, OBID on Server B: 1675
# Domain: link          OBID on Server A: 7836, OBID on Server B: 1155
# Domain: interface     OBID on Server A: 6103, OBID on Server B: 1679
# Domain: interface     OBID on Server A: 6127, OBID on Server B: 1658
# Domain: link          OBID on Server A: 7835, OBID on Server B: 1146
# Domain: interface     OBID on Server A: 6131, OBID on Server B: 1660
# Domain: interface     OBID on Server A: 6091, OBID on Server B: 1654
# Domain: link          OBID on Server A: 7837, OBID on Server B: 1133
# Domain: interface     OBID on Server A: 6092, OBID on Server B: 1648
# Domain: interface     OBID on Server A: 6154, OBID on Server B: 1707
# Domain: interface     OBID on Server A: 6143, OBID on Server B: 1715
# Domain: interface     OBID on Server A: 6153, OBID on Server B: 1698
# Domain: link          OBID on Server A: 7854, not found on Server B
# Domain: interface     OBID on Server A: 6105, OBID on Server B: 1673
# Domain: interface     OBID on Server A: 6141, OBID on Server B: 1716
# Domain: link          OBID on Server A: 7819, OBID on Server B: 1150
# Domain: interface     OBID on Server A: 6131, OBID on Server B: 1660
# Domain: interface     OBID on Server A: 6154, OBID on Server B: 1707
# Domain: link          OBID on Server A: 7832, OBID on Server B: 1130
# Domain: interface     OBID on Server A: 6103, OBID on Server B: 1679
# Domain: interface     OBID on Server A: 6156, OBID on Server B: 1706
# Domain: link          OBID on Server A: 7830, OBID on Server B: 1126
# Domain: interface     OBID on Server A: 6092, OBID on Server B: 1648
# Domain: interface     OBID on Server A: 6153, OBID on Server B: 1698
# Domain: link          OBID on Server A: 7826, OBID on Server B: 1129
# Domain: interface     OBID on Server A: 6131, OBID on Server B: 1660
# Domain: interface     OBID on Server A: 6147, OBID on Server B: 1693
# Domain: link          OBID on Server A: 7817, OBID on Server B: 1137
# Domain: interface     OBID on Server A: 6147, OBID on Server B: 1693
# Domain: interface     OBID on Server A: 6158, OBID on Server B: 1711
# Domain: link          OBID on Server A: 7844, OBID on Server B: 1127
# Domain: interface     OBID on Server A: 6092, OBID on Server B: 1648
# Domain: interface     OBID on Server A: 6137, OBID on Server B: 1722
# Domain: link          OBID on Server A: 7831, OBID on Server B: 1147
# Domain: interface     OBID on Server A: 6092, OBID on Server B: 1648
# Domain: interface     OBID on Server A: 6105, OBID on Server B: 1673
# Domain: link          OBID on Server A: 7847, OBID on Server B: 1141
# Domain: interface     OBID on Server A: 6103, OBID on Server B: 1679
# Domain: interface     OBID on Server A: 6148, OBID on Server B: 1694
# Domain: interface     OBID on Server A: 2327, OBID on Server B: 1589
# Domain: interface     OBID on Server A: 6097, OBID on Server B: 1656
# Domain: interface     OBID on Server A: 2327, OBID on Server B: 1589
# Domain: interface     OBID on Server A: 6159, OBID on Server B: 1705
# Domain: device        OBID on Server A: 1061, OBID on Server B: 1037
# Domain: interface     OBID on Server A: 6106, OBID on Server B: 1680
# Domain: interface     OBID on Server A: 2327, OBID on Server B: 1589
# Domain: interface     OBID on Server A: 6152, OBID on Server B: 1701
# Domain: interface     OBID on Server A: 6106, OBID on Server B: 1680
# Domain: interface     OBID on Server A: 5935, OBID on Server B: 1643
# Domain: interface     OBID on Server A: 2327, OBID on Server B: 1589
# Domain: interface     OBID on Server A: 6110, OBID on Server B: 1681
# Domain: interface     OBID on Server A: 2327, OBID on Server B: 1589
# Domain: interface     OBID on Server A: 6140, OBID on Server B: 1721
# Domain: interface     OBID on Server A: 2327, OBID on Server B: 1589
# Domain: interface     OBID on Server A: 6106, OBID on Server B: 1680
# Domain: interface     OBID on Server A: 2327, OBID on Server B: 1589
# Domain: interface     OBID on Server A: 6113, OBID on Server B: 1684
# Domain: interface     OBID on Server A: 2327, OBID on Server B: 1589
# Domain: interface     OBID on Server A: 6125, OBID on Server B: 1667
# Domain: link          OBID on Server A: 7875, OBID on Server B: 1095
# Domain: interface     OBID on Server A: 5922, OBID on Server B: 1579
# Domain: interface     OBID on Server A: 6450, OBID on Server B: 1289
# Domain: interface     OBID on Server A: 6448, OBID on Server B: 1296
# Domain: interface     OBID on Server A: 6366, OBID on Server B: 1235
# Domain: interface     OBID on Server A: 6296, OBID on Server B: 1184
# Domain: interface     OBID on Server A: 6203, OBID on Server B: 1026
# Domain: interface     OBID on Server A: 6288, OBID on Server B: 1194
# Domain: interface     OBID on Server A: 6195, OBID on Server B: 1049
# Domain: link          OBID on Server A: 7881, OBID on Server B: 1096
# Domain: interface     OBID on Server A: 5922, OBID on Server B: 1579
# Domain: interface     OBID on Server A: 6531, OBID on Server B: 1400
# Domain: link          OBID on Server A: 7902, OBID on Server B: 1091
# Domain: interface     OBID on Server A: 5922, OBID on Server B: 1579
# Domain: interface     OBID on Server A: 6480, OBID on Server B: 1375
# Domain: link          OBID on Server A: 7893, OBID on Server B: 1094
# Domain: interface     OBID on Server A: 5922, OBID on Server B: 1579
# Domain: interface     OBID on Server A: 6300, OBID on Server B: 1197
# Domain: link          OBID on Server A: 7877, OBID on Server B: 1006
# Domain: interface     OBID on Server A: 6431, OBID on Server B: 1270
# Domain: interface     OBID on Server A: 6503, OBID on Server B: 1326
# Domain: interface     OBID on Server A: 6507, OBID on Server B: 1312
# Domain: interface     OBID on Server A: 6455, OBID on Server B: 1266
# Domain: link          OBID on Server A: 7890, not found on Server B
# Domain: interface     OBID on Server A: 6330, OBID on Server B: 1177
# Domain: interface     OBID on Server A: 6527, OBID on Server B: 1402
# Domain: interface     OBID on Server A: 6418, OBID on Server B: 1293
# Domain: interface     OBID on Server A: 6530, OBID on Server B: 1403
# Domain: link          OBID on Server A: 7864, OBID on Server B: 1013
# Domain: interface     OBID on Server A: 6437, OBID on Server B: 1288
# Domain: interface     OBID on Server A: 6536, OBID on Server B: 1379
# Domain: link          OBID on Server A: 7856, OBID on Server B: 1011
# Domain: interface     OBID on Server A: 6402, OBID on Server B: 1207
# Domain: interface     OBID on Server A: 6475, OBID on Server B: 1313
# Domain: interface     OBID on Server A: 6354, OBID on Server B: 1256
# Domain: interface     OBID on Server A: 6484, OBID on Server B: 1335
# Domain: interface     OBID on Server A: 6457, OBID on Server B: 1330
# Domain: interface     OBID on Server A: 6178, OBID on Server B: 1048
# Domain: link          OBID on Server A: 7903, OBID on Server B: 1097
# Domain: interface     OBID on Server A: 5922, OBID on Server B: 1579
# Domain: interface     OBID on Server A: 6181, OBID on Server B: 1041
# Domain: interface     OBID on Server A: 6552, OBID on Server B: 1323
# Domain: interface     OBID on Server A: 6505, OBID on Server B: 1314
# Domain: interface     OBID on Server A: 6525, OBID on Server B: 1334
# Domain: interface     OBID on Server A: 6312, OBID on Server B: 1140
# Domain: link          OBID on Server A: 7859, OBID on Server B: 1085
# Domain: interface     OBID on Server A: 5922, OBID on Server B: 1579
# Domain: interface     OBID on Server A: 6371, OBID on Server B: 1229
# Domain: interface     OBID on Server A: 6470, OBID on Server B: 1316
# Domain: interface     OBID on Server A: 6213, OBID on Server B: 1071
# Domain: link          OBID on Server A: 7878, not found on Server B
# Domain: interface     OBID on Server A: 6395, OBID on Server B: 1214
# Domain: interface     OBID on Server A: 6423, OBID on Server B: 1294
# Domain: interface     OBID on Server A: 6502, OBID on Server B: 1384
# Domain: interface     OBID on Server A: 6516, OBID on Server B: 1374
# vLab transferred from 10.20.20.21 to 10.20.20.162
